# %% [markdown]
# Datensatz laden und verstehen

# %%
import pandas as pd

# %%
# Lade den Datensatz
df = pd.read_csv("cox2.csv")

# Zeige die Dimensionen des Datensatzes
print("Shape of dataset:", df.shape)

# Zeige die ersten 5 Zeilen
print("First 5 rows:")
print(df.head())

# Übersicht über die Spalten
print("\nColumn info:")
print(df.info())

# Grundlegende Statistik
print("\nDescriptive statistics:")
print(df.describe(include='all'))
# Out:
# Shape of dataset: (462, 257)
# First 5 rows:
#    QikProp_.stars  QikProp_.amine  QikProp_.acid  QikProp_.rotor  \
# 0               1               0              0               1
# 1               0               0              0               2
# 2               0               0              0               3
# 3               1               0              0               2
# 4               1               0              0               2
#
#    QikProp_.rctvFG  QikProp_CNS  QikProp_MW  QikProp_dipole  QikProp_SASA  \
# 0                0            0     358.882           7.645       635.022
# 1                0           -1     359.870           7.959       622.548
# 2                0           -1     355.451           7.500       610.972
# 3                0           -1     393.423           9.342       651.852
# 4                0           -1     394.315           9.409       637.688
#
#    QikProp_FOSA  ...  moe2D_vsa_acc  moe2D_vsa_don  moe2D_vsa_hyd  \
# 0       273.363  ...          32.02           0.00          268.2
# 1       189.930  ...          32.02          20.14          236.8
# 2       268.526  ...          34.52          20.14          238.4
# 3       190.772  ...          32.02          20.14          249.7
# 4       189.933  ...          32.02          20.14          255.1
#
#    moe2D_vsa_other  moe2D_vsa_pol  moe2D_weinerPath  moe2D_weinerPol  \
# 0            6.513            0.0              1340               37
# 1           10.110            0.0              1340               37
# 2           18.560            0.0              1524               39
# 3           10.110            0.0              1898               43
# 4           10.110            0.0              1486               40
#
#    moe2D_zagreb   IC50  cox2Class
# 0           138  0.001   Inactive
# 1           138  0.001   Inactive
# 2           142  0.001   Inactive
# 3           156  0.001   Inactive
# 4           144  0.001   Inactive
#
# [5 rows x 257 columns]
#
# Column info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 462 entries, 0 to 461
# Columns: 257 entries, QikProp_.stars to cox2Class
# dtypes: float64(212), int64(44), object(1)
# memory usage: 927.7+ KB
# None
#
# Descriptive statistics:
#         QikProp_.stars  QikProp_.amine  QikProp_.acid  QikProp_.rotor  \
# count       462.000000      462.000000     462.000000      462.000000
# unique             NaN             NaN            NaN             NaN
# top                NaN             NaN            NaN             NaN
# freq               NaN             NaN            NaN             NaN
# mean          0.885281        0.006494       0.012987        2.354978
# std           0.944122        0.080407       0.113341        1.265068
# min           0.000000        0.000000       0.000000        0.000000
# 25%           0.000000        0.000000       0.000000        1.000000
# 50%           1.000000        0.000000       0.000000        2.000000
# 75%           1.000000        0.000000       0.000000        3.000000
# max           5.000000        1.000000       1.000000        7.000000
#
#         QikProp_.rctvFG  QikProp_CNS  QikProp_MW  QikProp_dipole  \
# count        462.000000   462.000000  462.000000      462.000000
# unique              NaN          NaN         NaN             NaN
# top                 NaN          NaN         NaN             NaN
# freq                NaN          NaN         NaN             NaN
# mean           0.034632    -0.712121  391.315463        6.117706
# std            0.183044     0.834079   39.467535        1.879596
# min            0.000000    -2.000000  288.272000        0.485000
# 25%            0.000000    -1.000000  365.655000        4.573250
# 50%            0.000000    -1.000000  389.140500        6.216000
# 75%            0.000000     0.000000  413.727500        7.529750
# max            1.000000     2.000000  554.176000       11.330000
#
#         QikProp_SASA  QikProp_FOSA  ...  moe2D_vsa_acc  moe2D_vsa_don  \
# count     462.000000    462.000000  ...     462.000000     462.000000
# unique           NaN           NaN  ...            NaN            NaN
# top              NaN           NaN  ...            NaN            NaN
# freq             NaN           NaN  ...            NaN            NaN
# mean      620.402058    132.515318  ...      39.215697       9.061422
# std        45.572316     86.137857  ...       7.757616      10.308707
# min       507.148000      0.000000  ...       9.421000       0.000000
# 25%       593.268500     80.192750  ...      34.520000       0.000000
# 50%       612.469500    130.399000  ...      37.700000       0.000000
# 75%       638.628250    174.370250  ...      41.440000      20.140000
# max       813.620000    362.341000  ...      73.450000      37.880000
#
#         moe2D_vsa_hyd  moe2D_vsa_other  moe2D_vsa_pol  moe2D_weinerPath  \
# count      462.000000       462.000000     462.000000        462.000000
# unique            NaN              NaN            NaN               NaN
# top               NaN              NaN            NaN               NaN
# freq              NaN              NaN            NaN               NaN
# mean       255.016017        27.182597       0.845065       1727.837662
# std         35.246228        11.794566       4.077127        424.623061
# min        169.000000         6.513000       0.000000        875.000000
# 25%        229.825000        18.560000       0.000000       1475.000000
# 50%        254.100000        30.200000       0.000000       1654.000000
# 75%        275.875000        35.070000       0.000000       1985.000000
# max        383.200000        55.760000      27.130000       3934.000000
#
#         moe2D_weinerPol  moe2D_zagreb        IC50  cox2Class
# count        462.000000    462.000000  462.000000        462
# unique              NaN           NaN         NaN          2
# top                 NaN           NaN         NaN   Inactive
# freq                NaN           NaN         NaN        372
# mean          41.937229    142.450216   14.478609        NaN
# std            4.605283     13.065690   32.823922        NaN
# min           31.000000    112.000000    0.001000        NaN
# 25%           39.000000    134.000000    0.021000        NaN
# 50%           42.000000    142.000000    0.120000        NaN
# 75%           45.000000    151.500000    1.522500        NaN
# max           60.000000    196.000000  100.000000        NaN
#
# [11 rows x 257 columns]

# %% [markdown]
# Datensatz in Trainings- und Testdaten splitten

# %% [markdown]
# 4_4 letzter Punkt: accuracy, wie viele label richtig, genauigkeit. Capa?

# %%
from sklearn.model_selection import train_test_split

# %%
#Zielvariable ermitteln
print(df.columns)             
print(df.nunique())           
print(df.head())
# Out:
# Index(['QikProp_.stars', 'QikProp_.amine', 'QikProp_.acid', 'QikProp_.rotor',
#        'QikProp_.rctvFG', 'QikProp_CNS', 'QikProp_MW', 'QikProp_dipole',
#        'QikProp_SASA', 'QikProp_FOSA',
#        ...
#        'moe2D_vsa_acc', 'moe2D_vsa_don', 'moe2D_vsa_hyd', 'moe2D_vsa_other',
#        'moe2D_vsa_pol', 'moe2D_weinerPath', 'moe2D_weinerPol', 'moe2D_zagreb',
#        'IC50', 'cox2Class'],
#       dtype='object', length=257)
# QikProp_.stars        6
# QikProp_.amine        2
# QikProp_.acid         2
# QikProp_.rotor        8
# QikProp_.rctvFG       2
#                    ...
# moe2D_weinerPath    169
# moe2D_weinerPol      25
# moe2D_zagreb         32
# IC50                196
# cox2Class             2
# Length: 257, dtype: int64
#    QikProp_.stars  QikProp_.amine  QikProp_.acid  QikProp_.rotor  \
# 0               1               0              0               1
# 1               0               0              0               2
# 2               0               0              0               3
# 3               1               0              0               2
# 4               1               0              0               2
#
#    QikProp_.rctvFG  QikProp_CNS  QikProp_MW  QikProp_dipole  QikProp_SASA  \
# 0                0            0     358.882           7.645       635.022
# 1                0           -1     359.870           7.959       622.548
# 2                0           -1     355.451           7.500       610.972
# 3                0           -1     393.423           9.342       651.852
# 4                0           -1     394.315           9.409       637.688
#
#    QikProp_FOSA  ...  moe2D_vsa_acc  moe2D_vsa_don  moe2D_vsa_hyd  \
# 0       273.363  ...          32.02           0.00          268.2
# 1       189.930  ...          32.02          20.14          236.8
# 2       268.526  ...          34.52          20.14          238.4
# 3       190.772  ...          32.02          20.14          249.7
# 4       189.933  ...          32.02          20.14          255.1
#
#    moe2D_vsa_other  moe2D_vsa_pol  moe2D_weinerPath  moe2D_weinerPol  \
# 0            6.513            0.0              1340               37
# 1           10.110            0.0              1340               37
# 2           18.560            0.0              1524               39
# 3           10.110            0.0              1898               43
# 4           10.110            0.0              1486               40
#
#    moe2D_zagreb   IC50  cox2Class
# 0           138  0.001   Inactive
# 1           138  0.001   Inactive
# 2           142  0.001   Inactive
# 3           156  0.001   Inactive
# 4           144  0.001   Inactive
#
# [5 rows x 257 columns]

# %%
# Features und Ziel definieren
X = df.drop(columns=['cox2Class', 'IC50'])  # IC50 ebenfalls entfernen, da nicht als Feature
y = df['cox2Class']

# In numerische Klassen umwandeln (optional, je nach Modell)
y = y.map({'Inactive': 0, 'Active': 1})

# Split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42, stratify=y
)

print("Train shape:", X_train.shape)
print("Test shape:", X_test.shape)
# Out:
# Train shape: (346, 255)
# Test shape: (116, 255)

# %% [markdown]
# Klassifikation

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score

# %%
#Fehlende Werte füllen
X_train = X_train.fillna(0)
X_test = X_test.fillna(0)

# Random Forest Modell erstellen und trainieren
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)

# Vorhersage auf Testdaten
y_pred = rf.predict(X_test)

# Evaluation
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8362068965517241
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.94      0.90        93
#            1       0.62      0.43      0.51        23
#
#     accuracy                           0.84       116
#    macro avg       0.75      0.69      0.71       116
# weighted avg       0.82      0.84      0.82       116

# %% [markdown]
# Hyperparameter optimieren

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

# %%
# Parameter-Grid definieren
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20, 30],
    'max_features': ['sqrt', 'log2', None]  # entspricht mtry in R
}

# Random Forest Modell
rf = RandomForestClassifier(random_state=42)

# GridSearchCV Setup
grid_search = GridSearchCV(
    estimator=rf,
    param_grid=param_grid,
    cv=5,                 
    scoring='accuracy',  
    n_jobs=-1,            
    verbose=2
)

# Fit auf Trainingsdaten
grid_search.fit(X_train, y_train)

# Beste Parameter
print("Best parameters:", grid_search.best_params_)
print("Best cross-validation score:", grid_search.best_score_)

# Bestes Modell anwenden
best_rf = grid_search.best_estimator_
y_pred = best_rf.predict(X_test)

# Evaluation
from sklearn.metrics import classification_report, accuracy_score
print("\nTest Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV] END max_depth=None, max_features=sqrt, n_estimators=100; total time=   0.2s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=100; total time=   0.2s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=100; total time=   0.2s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=100; total time=   0.2s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=100; total time=   0.2s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=200; total time=   0.5s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=200; total time=   0.5s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=200; total time=   0.5s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=200; total time=   0.4s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=200; total time=   0.5s
# [CV] END max_depth=None, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, max_features=log2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=None, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=300; total time=   0.7s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=300; total time=   0.7s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=300; total time=   0.7s
# [CV] END max_depth=None, max_features=log2, n_estimators=200; total time=   0.3s
# [CV] END max_depth=None, max_features=log2, n_estimators=200; total time=   0.4s
# [CV] END max_depth=None, max_features=log2, n_estimators=200; total time=   0.3s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=300; total time=   0.7s
# [CV] END max_depth=None, max_features=log2, n_estimators=200; total time=   0.3s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=300; total time=   0.8s
# [CV] END max_depth=None, max_features=log2, n_estimators=200; total time=   0.3s
# [CV] END max_depth=None, max_features=log2, n_estimators=300; total time=   0.5s
# [CV] END max_depth=None, max_features=log2, n_estimators=300; total time=   0.4s
# [CV] END max_depth=None, max_features=log2, n_estimators=300; total time=   0.4s
# [CV] END max_depth=None, max_features=log2, n_estimators=300; total time=   0.5s
# [CV] END max_depth=None, max_features=log2, n_estimators=300; total time=   0.5s
# [CV] END max_depth=None, max_features=None, n_estimators=100; total time=   2.3s
# [CV] END max_depth=None, max_features=None, n_estimators=100; total time=   2.4s
# [CV] END max_depth=None, max_features=None, n_estimators=100; total time=   2.6s
# [CV] END max_depth=None, max_features=None, n_estimators=100; total time=   2.4s
# [CV] END max_depth=None, max_features=None, n_estimators=100; total time=   2.4s
# [CV] END max_depth=None, max_features=None, n_estimators=200; total time=   4.4s
# [CV] END max_depth=None, max_features=None, n_estimators=200; total time=   4.8s
# [CV] END max_depth=None, max_features=None, n_estimators=200; total time=   5.2s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=100; total time=   0.2s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=100; total time=   0.2s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=100; total time=   0.3s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=100; total time=   0.2s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=100; total time=   0.2s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=200; total time=   0.4s
# [CV] END max_depth=None, max_features=None, n_estimators=200; total time=   4.8s
# [CV] END max_depth=None, max_features=None, n_estimators=200; total time=   5.2s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=200; total time=   0.4s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=200; total time=   0.4s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=200; total time=   0.3s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=200; total time=   0.3s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=300; total time=   0.6s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=300; total time=   0.5s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=300; total time=   0.5s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=300; total time=   0.5s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=300; total time=   0.6s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=100; total time=   0.2s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=   0.2s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=   0.3s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=   0.3s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=   0.3s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=200; total time=   0.3s
# [CV] END max_depth=None, max_features=None, n_estimators=300; total time=   6.9s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=300; total time=   0.4s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=300; total time=   0.4s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=300; total time=   0.4s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=300; total time=   0.4s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=300; total time=   0.4s
# [CV] END max_depth=None, max_features=None, n_estimators=300; total time=   7.6s
# [CV] END max_depth=None, max_features=None, n_estimators=300; total time=   7.7s
# [CV] END ..max_depth=10, max_features=None, n_estimators=100; total time=   2.0s
# [CV] END ..max_depth=10, max_features=None, n_estimators=100; total time=   1.9s
# [CV] END max_depth=None, max_features=None, n_estimators=300; total time=   7.2s
# [CV] END ..max_depth=10, max_features=None, n_estimators=100; total time=   2.2s
# [CV] END ..max_depth=10, max_features=None, n_estimators=100; total time=   2.1s
# [CV] END ..max_depth=10, max_features=None, n_estimators=100; total time=   2.1s
# [CV] END max_depth=None, max_features=None, n_estimators=300; total time=   7.7s
# [CV] END ..max_depth=10, max_features=None, n_estimators=200; total time=   3.9s
# [CV] END ..max_depth=10, max_features=None, n_estimators=200; total time=   4.5s
# [CV] END ..max_depth=10, max_features=None, n_estimators=200; total time=   4.3s
# [CV] END ..max_depth=10, max_features=None, n_estimators=200; total time=   4.4s
# [CV] END ..max_depth=10, max_features=None, n_estimators=200; total time=   4.3s
# [CV] END ..max_depth=20, max_features=sqrt, n_estimators=100; total time=   0.3s
# [CV] END ..max_depth=20, max_features=sqrt, n_estimators=100; total time=   0.3s
# [CV] END ..max_depth=20, max_features=sqrt, n_estimators=100; total time=   0.2s
# [CV] END ..max_depth=20, max_features=sqrt, n_estimators=100; total time=   0.2s
# [CV] END ..max_depth=20, max_features=sqrt, n_estimators=100; total time=   0.2s
# [CV] END ..max_depth=20, max_features=sqrt, n_estimators=200; total time=   0.4s
# [CV] END ..max_depth=20, max_features=sqrt, n_estimators=200; total time=   0.6s
# [CV] END ..max_depth=20, max_features=sqrt, n_estimators=200; total time=   0.5s
# [CV] END ..max_depth=20, max_features=sqrt, n_estimators=200; total time=   0.4s
# [CV] END ..max_depth=20, max_features=sqrt, n_estimators=200; total time=   0.5s
# [CV] END ..max_depth=20, max_features=sqrt, n_estimators=300; total time=   0.6s
# [CV] END ..max_depth=10, max_features=None, n_estimators=300; total time=   6.0s
# [CV] END ..max_depth=20, max_features=sqrt, n_estimators=300; total time=   0.6s
# [CV] END ..max_depth=20, max_features=sqrt, n_estimators=300; total time=   0.6s
# [CV] END ..max_depth=20, max_features=log2, n_estimators=100; total time=   0.2s
# [CV] END ..max_depth=20, max_features=log2, n_estimators=100; total time=   0.2s
# [CV] END ..max_depth=20, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END ..max_depth=20, max_features=sqrt, n_estimators=300; total time=   0.7s
# [CV] END ..max_depth=20, max_features=log2, n_estimators=100; total time=   0.2s
# [CV] END ..max_depth=20, max_features=log2, n_estimators=100; total time=   0.2s
# [CV] END ..max_depth=20, max_features=sqrt, n_estimators=300; total time=   0.7s
# [CV] END ..max_depth=20, max_features=log2, n_estimators=200; total time=   0.3s
# [CV] END ..max_depth=10, max_features=None, n_estimators=300; total time=   6.6s
# [CV] END ..max_depth=20, max_features=log2, n_estimators=200; total time=   0.3s
# [CV] END ..max_depth=20, max_features=log2, n_estimators=200; total time=   0.3s
# [CV] END ..max_depth=10, max_features=None, n_estimators=300; total time=   6.3s
# [CV] END ..max_depth=20, max_features=log2, n_estimators=200; total time=   0.3s
# [CV] END ..max_depth=20, max_features=log2, n_estimators=200; total time=   0.3s
# [CV] END ..max_depth=20, max_features=log2, n_estimators=300; total time=   0.4s
# [CV] END ..max_depth=20, max_features=log2, n_estimators=300; total time=   0.4s
# [CV] END ..max_depth=20, max_features=log2, n_estimators=300; total time=   0.4s
# [CV] END ..max_depth=20, max_features=log2, n_estimators=300; total time=   0.4s
# [CV] END ..max_depth=20, max_features=log2, n_estimators=300; total time=   0.6s
# [CV] END ..max_depth=10, max_features=None, n_estimators=300; total time=   6.4s
# [CV] END ..max_depth=20, max_features=None, n_estimators=100; total time=   2.2s
# [CV] END ..max_depth=20, max_features=None, n_estimators=100; total time=   2.2s
# [CV] END ..max_depth=20, max_features=None, n_estimators=100; total time=   2.2s
# [CV] END ..max_depth=20, max_features=None, n_estimators=100; total time=   2.4s
# [CV] END ..max_depth=20, max_features=None, n_estimators=100; total time=   2.7s
# [CV] END ..max_depth=10, max_features=None, n_estimators=300; total time=   6.6s
# [CV] END ..max_depth=20, max_features=None, n_estimators=200; total time=   4.2s
# [CV] END ..max_depth=20, max_features=None, n_estimators=200; total time=   4.8s
# [CV] END ..max_depth=20, max_features=None, n_estimators=200; total time=   4.6s
# [CV] END ..max_depth=20, max_features=None, n_estimators=200; total time=   4.9s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=100; total time=   0.2s
# [CV] END ..max_depth=20, max_features=None, n_estimators=200; total time=   5.1s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=100; total time=   0.2s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=100; total time=   0.2s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=100; total time=   0.2s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=100; total time=   0.2s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=200; total time=   0.4s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=200; total time=   0.4s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=200; total time=   0.5s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=200; total time=   0.3s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=200; total time=   0.4s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=300; total time=   0.6s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=300; total time=   0.6s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=300; total time=   0.6s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=100; total time=   0.2s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=100; total time=   0.2s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=300; total time=   0.7s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=100; total time=   0.2s
# [CV] END ..max_depth=30, max_features=sqrt, n_estimators=300; total time=   0.7s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END ..max_depth=20, max_features=None, n_estimators=300; total time=   6.9s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=200; total time=   0.3s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=200; total time=   0.3s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=200; total time=   0.2s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=200; total time=   0.2s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=200; total time=   0.5s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=300; total time=   0.4s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=300; total time=   0.4s
# [CV] END ..max_depth=20, max_features=None, n_estimators=300; total time=   7.5s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=300; total time=   0.4s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=300; total time=   0.4s
# [CV] END ..max_depth=30, max_features=log2, n_estimators=300; total time=   0.5s
# [CV] END ..max_depth=20, max_features=None, n_estimators=300; total time=   8.0s
# [CV] END ..max_depth=20, max_features=None, n_estimators=300; total time=   7.2s
# [CV] END ..max_depth=30, max_features=None, n_estimators=100; total time=   2.2s
# [CV] END ..max_depth=30, max_features=None, n_estimators=100; total time=   2.4s
# [CV] END ..max_depth=30, max_features=None, n_estimators=100; total time=   2.4s
# [CV] END ..max_depth=30, max_features=None, n_estimators=100; total time=   2.7s
# [CV] END ..max_depth=30, max_features=None, n_estimators=100; total time=   2.4s
# [CV] END ..max_depth=20, max_features=None, n_estimators=300; total time=   7.3s
# [CV] END ..max_depth=30, max_features=None, n_estimators=200; total time=   4.4s
# [CV] END ..max_depth=30, max_features=None, n_estimators=200; total time=   5.2s
# [CV] END ..max_depth=30, max_features=None, n_estimators=200; total time=   4.8s
# [CV] END ..max_depth=30, max_features=None, n_estimators=200; total time=   5.0s
# [CV] END ..max_depth=30, max_features=None, n_estimators=200; total time=   5.3s
# [CV] END ..max_depth=30, max_features=None, n_estimators=300; total time=   6.3s
# [CV] END ..max_depth=30, max_features=None, n_estimators=300; total time=   6.5s
# [CV] END ..max_depth=30, max_features=None, n_estimators=300; total time=   6.9s
# [CV] END ..max_depth=30, max_features=None, n_estimators=300; total time=   5.8s
# [CV] END ..max_depth=30, max_features=None, n_estimators=300; total time=   5.4s
# Best parameters: {'max_depth': None, 'max_features': None, 'n_estimators': 100}
# Best cross-validation score: 0.8554865424430643
#
# Test Accuracy: 0.8448275862068966
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.92      0.91        93
#            1       0.63      0.52      0.57        23
#
#     accuracy                           0.84       116
#    macro avg       0.76      0.72      0.74       116
# weighted avg       0.84      0.84      0.84       116
